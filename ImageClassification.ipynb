# %%
# !pip install tensorflow tflite opencv-python matplotlib
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\alexa\dropbox\uwo\eng\capstone\ai\capstone\lib\site-packages\apache_beam-2.54.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\alexa\dropbox\uwo\eng\capstone\ai\capstone\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\alexa\dropbox\uwo\eng\capstone\ai\capstone\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
import tensorflow as tf
import os
# Out:
# WARNING:tensorflow:From C:\Users\alexa\Dropbox\UWO\Eng\Capstone\AI\capstone\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
labels = ['glass', 'metal', 'paper', 'plastic', 'trash']

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\alexa\dropbox\uwo\eng\capstone\ai\capstone\lib\site-packages\apache_beam-2.54.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\alexa\dropbox\uwo\eng\capstone\ai\capstone\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\alexa\dropbox\uwo\eng\capstone\ai\capstone\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:C:\Users\alexa\Dropbox\UWO\Eng\Capstone\AI\Tensorflow\workspace\images\collectedimages\glass\glass1.jpg -> Annotation:C:/Users/alexa/Dropbox/UWO/Eng/Capstone/AI/Tensorflow/workspace/images/collectedimages/glass\glass1.xml
# Image:C:\Users\alexa\Dropbox\UWO\Eng\Capstone\AI\Tensorflow\workspace\images\collectedimages\glass\glass1.jpg -> Annotation:C:/Users/alexa/Dropbox/UWO/Eng/Capstone/AI/Tensorflow/workspace/images/collectedimages/glass\glass1.xml
# Image:C:\Users\alexa\Dropbox\UWO\Eng\Capstone\AI\Tensorflow\workspace\images\collectedimages\glass\glass2.jpg -> Annotation:C:/Users/alexa/Dropbox/UWO/Eng/Capstone/AI/Tensorflow/workspace/images/collectedimages/glass\glass2.xml
# Image:C:\Users\alexa\Dropbox\UWO\Eng\Capstone\AI\Tensorflow\workspace\images\collectedimages\glass\glass3.jpg -> Annotation:C:/Users/alexa/Dropbox/UWO/Eng/Capstone/AI/Tensorflow/workspace/images/collectedimages/glass\glass3.xml
# ...

# %%
directory = "extratest"

# %%
os.getcwd()
# Out:
# 'C:\\Users\\alexa\\Dropbox\\UWO\\Eng\\Capstone\\AI'

# %%
import os
import xml.etree.ElementTree as ET

# %%
for filename in os.listdir(directory): 
    if filename.endswith(".jpg"):
        img_file_path = os.path.join(directory, filename) 
    if filename.endswith(".xml"): 
        file_path = os.path.join(directory, filename) 
         
        # Read and parse the XML file 
        tree = ET.parse(file_path) 
        root = tree.getroot() 
        objectcount = 0
        for child in root:
            if child.tag == 'object':
                objectcount += 1
        if objectcount > 1:
            os.remove(img_file_path)
            os.remove(file_path)

# %%
image = os.path.join(directory, 'glass488_jpg.rf.3283b31bdd3f412cf990cf827d8b2c7d.xml')
tree = ET.parse(file_path) 
root = tree.getroot() 
parent = root.find('object')
child = parent.find('bndbox')
        #print(child[0])
for child in child:
    if (int(child.text)) < 0:
        print(child.text)

# %%
directory = os.path.join('Tensorflow', 'workspace','images','train')

# %%
for filename in os.listdir(directory): 
    if filename.endswith(".xml"): 
        file_path = os.path.join(directory, filename) 
         
        # Read and parse the XML file 
        tree = ET.parse(file_path) 
        root = tree.getroot() 
        parent = root.find('object')
        
        parent.remove(parent.find('occluded'))
        tree.write(file_path)

# %%
for filename in os.listdir(directory): 
    if filename.endswith(".xml"): 
        file_path = os.path.join(directory, filename) 
         
        # Read and parse the XML file 
        tree = ET.parse(file_path) 
        root = tree.getroot() 
        parent = root.find('object')
        child = parent.find('bndbox')
        #print(child[0])
        for child in child:
            if int(child.text) < 0:
                print(file_path)
